# %%
import time
start_time = time.time()

import pandas as pd   # pandas for data frame organization
import numpy as np  # numpy for math stuff
from sklearn.linear_model import LogisticRegression  # Used Logistic Regression for prediction
from gensim.models.doc2vec import TaggedDocument
import nltk
import pickle
import random
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

print("--- %s seconds ---" % (time.time() - start_time))


punctuations = [",",".","(",")","-",".",'/'] #list of punctuations, expand if neccessary
new_model,logreg,sortedCompany = pickle.load(open("training_parameters.pkl","rb"))

lda_model_10, id2word, d_topic_10, converted_currency = pickle.load(open("stuff to run","rb"))
title_list = pickle.load(open("title list","rb"))
stop_words = set(stopwords.words('english'))
nlp = pickle.load(open("spacy.pkl","rb"))

def tokenize_text(text):
        #token a string into individual words
        tokens = []
        for sent in nltk.sent_tokenize(text):
            for word in nltk.word_tokenize(sent):
                if len(word) < 2:
                    continue
                tokens.append(word.lower())
        return tokens



def prediction(title):
    new_proj = title.lower()

    for punctuation in punctuations: #O(n)
            new_proj = " ".join(new_proj.split(punctuation))

    test_tagged = TaggedDocument(words=tokenize_text(new_proj), tags=['test'])
    
    X_test = (test_tagged.tags[0], new_model.infer_vector(test_tagged.words, epochs= 10000))


    # Predicted probability for each company to be involved in the new project
    y_prob = logreg.predict_proba([X_test[1]])[0]
    # print(y_prob)
    # Maximum probability (i.e the probability for most likely company)



    # Preparing the visualsation dataframe
    visData = pd.DataFrame({'Company':sortedCompany['Company'],'Probability':y_prob,"FG":sortedCompany['FG']})

    # We only plot company with more than 1 % chance of competing, since average about 3.9 per project. (would deem 1% to be reasonable) 
    plottingSet = visData.loc[visData['Probability'] >= 0.01]
    
    top5 = plottingSet.sort_values(by=['Probability'],ascending = False).head(5).astype(str)

    top5likely = list(top5['Company'].values)
    print(top5['FG'].values)
    print(list(zip(top5likely,top5['FG'].values)))
    return(list(zip(top5likely,top5['FG'].values)))

def get_value(sentence):

    predictions_for_amts_neo = clf_linear_reg.predict(x_test)

    test = np.array(get_topic(sentence))
    test = test.reshape(1,-1)
    return(round(max(float(clf_linear_reg.predict(test)),0),2),round(mean_absolute_error(y_test, predictions_for_amts_neo),2))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---
# --- 0.4617645740509033 seconds ---

# %%
import json
json.dumps(prediction("cloud service"))
# Out:
# ['3' '2' '2' '2' '6']
# [('starhub ltd.', '3'), ('wizlearn technologies pte. ltd.', '2'), ('ace-learning systems pte. ltd.', '2'), ('innov8te pte. ltd.', '2'), ('jardine onesolution(2001) pte ltd', '6')]
# '[["starhub ltd.", "wizlearn technologies pte. ltd.", "ace-learning systems pte. ltd.", "innov8te pte. ltd.", "jardine onesolution(2001) pte ltd"], ["3", "2", "2", "2", "6"]]'

# %%
float([2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-3a6e0f452c61> in <module>()
# ----> 1 float([2,3,4])
#
# TypeError: float() argument must be a string or a number, not 'list'

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://localhost:27017/") #Port
mydb = myclient["CompetitionIntellUpdated"]  #DB name
mycol = mydb["GeBizCollection"]  #Collection name

#Select only IT Service 408 entries out of 11k
myquery = { "ProcurementCategory": 'IT&Telecommunication ⇒ IT Services & Software Development '}  #Query
#print(myquery)
#myquery = {}
mydoc = mycol.find(myquery)
data = []
for x in mydoc:
    data.append(x)
for entry in data:
    if len(entry['Awards']) == 1:
        for i in range(len(entry['Respondents'])):
            entry[('Respondent'+str(i))] = entry['Respondents'][str(i)]['CompanyName']
            entry[('_Respondent'+str(i)+"Value")] = entry['Respondents'][str(i)]['TotalPrice']
        #print(entry['Awards'])
        entry['AwardedTo'] = entry['Awards'][str(0)]['AwardedTo']
        entry['AwardedValue'] = entry['Awards'][str(0)]['AwardedValue']
    elif len(entry['Awards']) > 1:
        #entry['AwardedTo'] = 'Multi'
        pass
        #data.remove(entry)
    else: # remove / just print anything for multiple award
        pass
        #data.remove(entry)
        
Rdata = []
for entry in data:
    try:
        for i in range(len(entry['Respondents'])):
            Rdata.append([entry['Respondents'][str(i)]['CompanyName'],entry['Respondents'][str(i)]['TotalPrice']])
    except:
        pass
Rdf = pd.DataFrame(Rdata)
Rdf.rename(columns={0:'Company',1:'Price'}, 
                 inplace=True)
def lowerCase(x):
    if isinstance(x, str):
        x = x.strip()
        return x.lower()
    return x

def convertToSGD(string):
    if isinstance(string, str):
        #print(string)
        x = string.split("(")
        amount = float(x[0])
        currency = x[1].strip()
        currency = currency[:-1]
        #print(amount)
        #print(currency)
        
        exchangeRate = {'sgd':1,'usd':1.36032,'eur':1.52292,
                        'myr':0.32874,'chf':1.33804,'gbp':1.76,
                        "aud":0.95,"cnh":0.2,"jpy":0.013,"qar":0.38,
                        "bnd":1,"aed":0.37,"nzd":0.9,"idr":0.000095,
                        "sek":0.14,"cad":1.02,"php":0.026,"inr":0.02}

        try:
            sgdValue = amount * exchangeRate[currency]
            return sgdValue
        except:
            try:
                currency = currency.split(")")[0]
                sgdValue = amount * exchangeRate[currency]
                return sgdValue
            except:
                print(currency)
def setFG(x):
    if x <= 100000:
        return 2
    elif x <= 250000:
        return 3
    elif x <= 500000:
        return 4
    elif x <= 1000000:
        return 5
    elif x <= 3000000:
        return 6
    elif x <= 5000000:
        return 7
    elif x <= 10000000:
        return 8
    elif x <= 30000000:
        return 9
    else:
        return 10
Rdf = Rdf.applymap(lowerCase)
Rdf['Price'] = Rdf['Price'].apply(convertToSGD)
Rdf = Rdf.dropna()
Company_data = Rdf.groupby('Company').max().reset_index()
Company_data['FG'] = Company_data['Price'].apply(setFG)
Company_data.set_index('Company',inplace=True)
test = pd.DataFrame(index=sortedCompany)
result = pd.concat([test, Company_data], axis=1, join='inner').reset_index()
result.rename(columns={"index":"Company"},inplace=True)
result
# Out:
#                                            Company        Price  FG
# 0                          1-net singapore pte ltd     12400.00   2
# 1                                 1arche pte. ltd.    361000.00   4
# 2            360solutions business consultancy llp     40000.00   2
# 3                  3d networks singapore pte. ltd.   1672546.00   6
# 4                              3g global pte. ltd.      8700.00   2
# 5                          a'cross media pte. ltd.      8800.00   2
# 6                      a-sonic logistics pte. ltd.     69360.00   2
# 7                       a-speed infotech pte. ltd.     17852.40   2
# 8                         aam geospatial pte. ltd.     38000.00   2
# 9                aaron wills & co. private limited     68400.00   2
# 10                     abi-tech solution pte. ltd.     68000.00   2
# 11                               accenture pte ltd  36223368.00  10
# 12   acclivis technologies and solutions pte. ltd.   1241687.00   6
# 13                              accura infosys llp   1362550.00   6
# 14                              accuracy pte. ltd.     71400.00   2
# 15                  ace-learning systems pte. ltd.     56100.00   2
# 16                     acecom technologies pte ltd     12640.00   2
# 17                              aceplp.com pte ltd    198888.00   3
# 18          acp computer training school pte. ltd.    454344.86   4
# 19                    activate interactive pte ltd    317400.00   4
# 20                     activeo singapore pte. ltd.    134531.92   3
# 21                                aculearn pte ltd     65000.00   2
# 22                         ad planet group pte ltd     76672.09   2
# 23                     addest technovation pte ltd      9109.00   2
# 24      adelphi digital consulting group pte. ltd.    261800.00   4
# 25                        ademco(far east) pte ltd    625740.00   5
# 26              admaterials technologies pte. ltd.       450.00   2
# 27                     adnovum singapore pte. ltd.    361582.00   4
# 28                   advancedata network pte. ltd.    278550.00   4
# 29                               aeterna solutions     30000.00   2
# ..                                             ...          ...  ..
# 648        vvolve management consultants pte. ltd.   1830547.29   6
# 649                          web igniter pte. ltd.    130550.00   3
# 650                 web professional house pte ltd    975828.00   5
# 651                       web synergies(s) pte ltd    498000.00   4
# 652                            websparks pte. ltd.    894033.00   5
# 653                               weighman pte ltd     74400.00   2
# 654                  white page creation pte. ltd.     68600.00   2
# 655                             whits technologies     13000.00   2
# 656                            whooshpro pte. ltd.     24600.00   2
# 657                    wipro networks pte. limited  13233909.85   9
# 658                wishbone design consultants llp     56000.00   2
# 659                               wiz werx pte ltd    126000.00   3
# 660                wizlearn technologies pte. ltd.     68500.00   2
# 661                            wizvision pte. ltd.    991258.00   5
# 662                        wongsign & ad pte. ltd.     22340.00   2
# 663                             wormwood pte. ltd.    496000.00   4
# 664                             ws group pte. ltd.     69400.00   2
# 665                       wsi laboratory pte. ltd.      6000.00   2
# 666                                    wunderfauks     65120.00   2
# 667                             xamariners pte ltd    130290.00   3
# 668                           xjera labs pte. ltd.    161580.00   3
# 669                         xssist group pte. ltd.      8628.00   2
# 670                    yamato transport(s) pte ltd    103680.00   3
# 671              yokogawa engineering asia pte ltd    830236.00   5
# 672                   yong lei logistics pte. ltd.     84960.00   2
# 673                 zencode technologies pte. ltd.    114400.00   3
# 674                    zenith infotech(s) pte ltd.    137136.00   3
# 675                    zentech solutions pte. ltd.     28800.00   2
# 676                            zoliotech pte. ltd.     40000.00   2
# 677                                zwaan pte. ltd.     27000.00   2
#
# [678 rows x 3 columns]

# %%
list(result['Company'])
# Out:
# ['1-net singapore pte ltd',
#  '1arche pte. ltd.',
#  '360solutions business consultancy llp',
#  '3d networks singapore pte. ltd.',
#  '3g global pte. ltd.',
#  "a'cross media pte. ltd.",
#  'a-sonic logistics pte. ltd.',
#  'a-speed infotech pte. ltd.',
#  'aam geospatial pte. ltd.',
#  'aaron wills & co. private limited',
#  'abi-tech solution pte. ltd.',
#  'accenture pte ltd',
#  'acclivis technologies and solutions pte. ltd.',
#  'accura infosys llp',
#  'accuracy pte. ltd.',
#  'ace-learning systems pte. ltd.',
#  'acecom technologies pte ltd',
#  'aceplp.com pte ltd',
#  'acp computer training school pte. ltd.',
#  'activate interactive pte ltd',
#  'activeo singapore pte. ltd.',
#  'aculearn pte ltd',
#  'ad planet group pte ltd',
#  'addest technovation pte ltd',
#  'adelphi digital consulting group pte. ltd.',
#  'ademco(far east) pte ltd',
#  'admaterials technologies pte. ltd.',
#  'adnovum singapore pte. ltd.',
#  'advancedata network pte. ltd.',
#  'aeterna solutions',
#  'affle global pte. ltd.',
#  'afizan pte ltd',
#  'aftershock pc pte. ltd.',
#  'aikguan marketing',
#  'akeles consulting pte. ltd.',
#  'alc technologies pte ltd',
#  'aleph pte. ltd.',
#  'alkem company(singapore) private limited',
#  'allan defence technologies pte. ltd.',
#  'alphanova pte. ltd.',
#  'alpsoft technologies pte. ltd.',
#  'altrocks tech pte. ltd.',
#  'amber creative pte. ltd.',
#  'amnet technology pte ltd',
#  'amobee group pte. ltd.',
#  'anacle systems limited',
#  'analytical technologies pte ltd',
#  'anuradha g kumar',
#  'app content & concepts pte. ltd.',
#  'appedia pte. ltd.',
#  'apptitude pte. ltd.',
#  'apro-asian protection pte ltd',
#  'arch software intelligence pte. ltd.',
#  'ardent business advisory pte. ltd.',
#  'arethos pte. ltd.',
#  'argsen pty. ltd.',
#  'arkemis pte. ltd.',
#  'arquis pte. ltd.',
#  'arrowcrest technologies pte ltd',
#  'ascenxus pte. ltd.',
#  'asiacloud solutions private limited',
#  'asiapac distribution pte ltd',
#  'asiasoft solutions pte. ltd.',
#  'asiatel(s) pte ltd',
#  'assure it pte. ltd.',
#  'athena dynamics pte. ltd.',
#  'atlas electronics resources pte. ltd.',
#  'atomz i! pte. ltd.',
#  'atos information technology(singapore) pte. ltd.',
#  "att systems(s'pore) pte ltd",
#  'audax visuals pte. ltd.',
#  'audiencevalue pte. ltd.',
#  'autopack pte ltd',
#  'avanta global pte. ltd.',
#  'avepoint singapore pte. ltd.',
#  'avero tech pte. ltd.',
#  'avery system',
#  'awecreation pte. ltd.',
#  'axentel technologies pte. ltd.',
#  'axiom it solutions pte. ltd.',
#  'axs pte. ltd.',
#  'azendian holding pte. ltd.',
#  'bahwan cybertek pte. ltd.',
#  'baize technology pte. ltd.',
#  'bamboo system technology pte. ltd.',
#  'bazingo inc. pte. ltd.',
#  'bc connex pte. ltd.',
#  'be.nergy pte. ltd.',
#  'bentley systems international limited',
#  'bh consulting services',
#  'bhavyam infotech services pte. ltd.',
#  'bibliotheca singapore pte. ltd.',
#  'bimage consulting pte. ltd.',
#  'binjai interior design pte ltd',
#  'bit solution pte. ltd.',
#  'bloom consulting services private limited',
#  'bloom consulting services pte. ltd.',
#  'blue wireless pte. ltd.',
#  'bms engineering and trading pte. ltd.',
#  'bridgenet solutions(singapore) pte. ltd.',
#  'brightsword technologies pte. ltd.',
#  'broadcast engineering services pte ltd',
#  'bt global solutions pte. ltd.',
#  'btw technology pte ltd',
#  'business edge personnel services pte ltd',
#  'butterfly global pte ltd',
#  'butterscotch creations pte. ltd.',
#  'bybitech llp',
#  'cak & fg survey pte. ltd.',
#  'calsius solutions pte. ltd.',
#  'calvin seng design',
#  'capio technologies pte. ltd.',
#  'casuarina services pte. ltd.',
#  'cavu corp pte. ltd.',
#  'centre for social emotional learning(sel)',
#  'certis cisco security pte. ltd.',
#  'certis technology(singapore) pte. ltd.',
#  'chesterfield pte. ltd.',
#  'china unicom(singapore) operations pte. ltd.',
#  'chs engineering services ltd',
#  'chubb singapore private limited',
#  'circus social pte. ltd.',
#  'civica pte. ltd.',
#  'cks global consultants pte. ltd.',
#  'clairvoyant lab',
#  'claned group oy ab',
#  'clarivate analytics us llc',
#  'cloudsquire pte. ltd.',
#  'cmg group(singapore) pte. ltd.',
#  'cns consultant',
#  'coachreg pte. ltd.',
#  'cognizant technology solutions asia pacific pte. ltd.',
#  'cohesion network technologies pte ltd',
#  'commontown private limited',
#  'computor lord industrial training centre',
#  'comwerks pte. ltd.',
#  'concentus pte. ltd.',
#  'conexus pte. ltd.',
#  'conglomerate of sapphiro',
#  'congress rental pte. ltd.',
#  'consapp pte. ltd.',
#  'consumer cloud technology services pte. ltd.',
#  'continuum systems pte ltd',
#  'conversion hub holdings pte. ltd.',
#  'corporate finedge pte. ltd',
#  'corts workshop',
#  'coselec pte ltd',
#  'couple creative private limited',
#  'craveative media',
#  'createsoft group pte. ltd.',
#  'creative education group pte ltd',
#  'crown worldwide pte ltd',
#  'cs global group pte. ltd.',
#  'csh educational resources pte ltd',
#  'ctc global pte. ltd.',
#  'customer capital consulting pte. ltd.',
#  'cutech infocomm solutions pte. ltd.',
#  'cutech solutions & services pte. ltd.',
#  'cxrus solutions pte. ltd.',
#  'cybertip technologies pte. ltd.',
#  'cynopsis solutions pte. ltd.',
#  'cypress labs pte. ltd.',
#  'd & g marketing pte. ltd.',
#  'd3 solutions pte. ltd.',
#  'dabton pte. ltd.',
#  'daemon enterprise pte ltd',
#  'daniel wireless software pte. ltd.',
#  'data connect technologies pte ltd',
#  'datacentric pte. ltd.',
#  'datapower system pte. ltd.',
#  'dc-fm pte. ltd.',
#  'delaware consulting asia pacific pte. ltd.',
#  'deloitte & touche enterprise risk services pte ltd',
#  'deloitte & touche llp',
#  'deltec marketing & engineering pte. ltd.',
#  'delteq pte ltd',
#  'den & den technology',
#  'dezainwerkz pte. ltd.',
#  'dezire technologies pte. ltd.',
#  'digimax sign engineering private limited',
#  'digital connect pte. ltd.',
#  'dimension data(singapore) pte. ltd.',
#  'dkt business services pte. ltd.',
#  'dong feng engineering works',
#  'dream catcher technologies pte. ltd.',
#  'dreamchasers interactive',
#  'dreamcloud pte. ltd.',
#  'dsmr group pte. ltd.',
#  'duck learning',
#  'dxc technology singapore pte. ltd.',
#  'e-com digital international pte ltd',
#  'e-com media international pte. ltd.',
#  'e-tag rfid pte. ltd.',
#  'eclatsoft pte. ltd.',
#  'ecosoft technologies',
#  'edu alliance private limited',
#  'edublitz pte ltd',
#  'edvantedge private limited',
#  'edward alexander varani',
#  'efre far east pte ltd',
#  'eg innovations pte. ltd.',
#  'el pando pte. ltd.',
#  'elc pte. ltd.',
#  'electra(s) pte. ltd.',
#  'elsevier b.v.',
#  'embrio enterprises pte. ltd.',
#  'emerio globesoft pte. ltd.',
#  'eminet pte. ltd.',
#  'ems wiring systems pte. ltd.',
#  'encora technologies pte. ltd.',
#  'engenuiz',
#  'entiis pte. ltd.',
#  'envirosolutions & consulting pte. ltd.',
#  'envis8ge pte. ltd.',
#  'envision enterprise solutions asia pacific pte. ltd.',
#  'ep-tec solutions pte ltd',
#  'epitomist pte. ltd.',
#  'eqcoms technology pte ltd',
#  'erideon private limited',
#  'ernst & young advisory pte. ltd.',
#  'ernst & young solutions llp',
#  'espire infolabs(singapore) pte. ltd.',
#  'eunix fire protection pte. ltd.',
#  'eureka! campaign associates pte. ltd.',
#  'euroline supplies pte. ltd.',
#  'evantek pte ltd',
#  'evvo labs pte. ltd.',
#  'excelasia it consulting pte. ltd.',
#  'excelsoft technologies pte. ltd.',
#  'experdex pte. ltd.',
#  'experience ace',
#  'exsys pte. ltd.',
#  'ezworld pte. ltd.',
#  'factiva limited',
#  'famegate studios pte. ltd.',
#  'fatiin multimedia pte ltd',
#  'fire armour pte. ltd.',
#  'firetronics(s) pte. ltd.',
#  'first sight international private limited',
#  'first technology(singapore) pte. ltd.',
#  'flexlink engineers pte ltd',
#  'fms hospitality pte. ltd.',
#  'fonbell solution pte. ltd.',
#  'force 21 equipment pte ltd',
#  'fpt asia pacific pte. ltd.',
#  'fuji xerox singapore pte ltd',
#  'fujitsu asia pte ltd',
#  'future senze pte. ltd.',
#  'futurex technologies pte ltd',
#  'fxmedia internet pte. ltd.',
#  'generic technologies(s) pte ltd',
#  'genesis networks pte ltd',
#  'geowalker pte. ltd.',
#  'global garments group pte. ltd.',
#  'global momentum pte. ltd.',
#  'gnowbe pte. ltd.',
#  'gothere private limited',
#  'green koncepts pte. ltd.',
#  'greystone consulting pte. ltd.',
#  'grid_synergy pte. ltd.',
#  'gururealiti pte. ltd.',
#  'hashtag interactive pte. ltd.',
#  'havas worldwide singapore pte. ltd.',
#  'hcl insys pte. ltd.',
#  'helius technologies pte. ltd.',
#  'hewlett-packard singapore(sales) pte. ltd.',
#  'heymath! innovation lab(s) pte. ltd.',
#  'hill & knowlton(sea) pte ltd',
#  'hitachi asia ltd.',
#  'hitachi systems digital services(singapore) pte. ltd.',
#  'hope technik pte. ltd.',
#  'hr path singapore pte. ltd.',
#  'huntington communications pte ltd',
#  'i-innova solutions pte. ltd.',
#  'i-magination solution pte. ltd.',
#  'i-sprint innovations pte ltd',
#  'i.d.s - ingegneria dei sistemi - s.p.a.',
#  'ibase technology private limited',
#  'ibm singapore pte ltd',
#  'icon media group pte. ltd.',
#  'icon resources and technologies pte ltd',
#  'ideal systems(singapore) pte. ltd.',
#  'idm lab sdn bhd',
#  'ih singapore pte. ltd.',
#  'iij global solutions singapore pte. ltd.',
#  'im3 asia pte. ltd.',
#  'imc information multimedia communication ag',
#  'imcomp international pte ltd',
#  'immersively pte. ltd.',
#  'incepte pte. ltd.',
#  'inchone pte. ltd.',
#  'infinito games pte. ltd.',
#  'infinity global solutions pte. ltd.',
#  'info lab pte. ltd.',
#  'infobip mobile services pte. ltd.',
#  'infocepts pte. ltd.',
#  'infognosis pte. ltd.',
#  'infonet systems and services pte ltd',
#  'informa solutions pte. ltd.',
#  'infowise',
#  'infront consulting group(s) pte. ltd.',
#  'ingenique solutions pte. ltd.',
#  'inginim pte. ltd.',
#  'inkspire group llp',
#  'innervative learning pte. ltd.',
#  'innocom technologies pte ltd',
#  'innov8te pte. ltd.',
#  'insider security pte. ltd.',
#  'inspire-tech pte ltd',
#  'inspius singapore pte. ltd.',
#  'institute of mental health',
#  'intellect group solutions',
#  'intelliswift software singapore pte. ltd.',
#  'intergraph security government & infrastructure pte. ltd.',
#  'interlace india private limited',
#  'intersoftkk(singapore) pte. ltd.',
#  'inventit technology pte. ltd.',
#  'invento asia pte. ltd.',
#  'ionesoft solutions pte. ltd.',
#  'ip-fm pte. ltd.',
#  'ipat holdings limited',
#  'iq dynamics pte ltd',
#  'irisnation singapore pte. ltd.',
#  'ishaan informatics pte. ltd.',
#  'it-bio pte. ltd.',
#  'itcan pte. limited',
#  'jadia logistics pte. ltd.',
#  'jardine onesolution(2001) pte ltd',
#  'jason electronics(pte) ltd',
#  'jme global pte. ltd.',
#  'jobkred private limited',
#  'jos applications(s) pte. ltd.',
#  'joyous se engineering',
#  'jung asia pte ltd',
#  'jusfeedback pte. ltd.',
#  'juzz web pte. ltd.',
#  'k&jj pte. ltd.',
#  'k. entry system pte ltd',
#  'katalystm pte. ltd.',
#  'kerry distribution(singapore) pte. ltd.',
#  'knowledge management solutions pte ltd',
#  'koh chin chin carol',
#  'konica minolta business solutions asia pte. ltd.',
#  'kpmg advisory services pte. ltd.',
#  'kpmg services pte. ltd.',
#  'krds digital pte. ltd.',
#  'kronos 313 pte. ltd.',
#  'kydon learning systems institute pte. ltd.',
#  'lai yew seng pte ltd',
#  'lantone systems pte. ltd.',
#  'ldr pte. ltd.',
#  'leacov singapore pte. ltd.',
#  'leap ds&c pte. ltd.',
#  'learnaholic pte. ltd.',
#  'lemonade it solutions pte. ltd.',
#  'leo infocomm pte ltd',
#  'lexisnexis',
#  'lexisnexis risk solutions uk limited',
#  'lga telecom pte ltd',
#  'links creation pte. ltd.',
#  'linkstreet learning private limited',
#  'lionfish studios pte. ltd.',
#  'litestar technologies pte. ltd.',
#  'litmus group pte. ltd.',
#  'logicalis singapore pte. ltd.',
#  'm1 limited',
#  'm1 net ltd.',
#  'm8m pte. ltd.',
#  'mastereign specialists pte. ltd.',
#  'maven lab private limited',
#  'maventree technology pte ltd',
#  'maximus consulting pte ltd',
#  'mc consulting pte. ltd.',
#  'mccann worldgroup(singapore) pte. ltd.',
#  'mediaonline international pte. ltd.',
#  'mediasoft integration pte. ltd.',
#  'mega laser support private limited',
#  'mega technology industrial pte. ltd.',
#  'megatrons pte. ltd.',
#  'meteorite asia enterprises pte. ltd.',
#  'mgg mobileapps private limited',
#  'micro express technologies',
#  'mindclick pte. ltd.',
#  'mitrais pt(foreign investment company)',
#  'mobile market monitor singapore pte. ltd.',
#  'mobile workforce solution pte. ltd.',
#  'mobiquest solutions pte. ltd.',
#  'mobtwo pte. ltd.',
#  'morilolo pte. ltd.',
#  'morven solutions(singapore) pte. ltd.',
#  'mq spectrum pte. ltd.',
#  'muse pte ltd',
#  'myasset pte. ltd.',
#  'nano equipment pte. ltd.',
#  'nanosoft business systems pte. ltd.',
#  'navblue wales limited',
#  'ncode consultant pte ltd',
#  'ncs pte. ltd.',
#  'nec asia pacific pte. ltd.',
#  'nera telecommunications ltd',
#  'netgain systems pte. ltd.',
#  'netpluz asia pte. ltd.',
#  'netroworkz pte. ltd.',
#  'network architects pte. ltd.',
#  'neubits pte. ltd.',
#  'newgens pte ltd',
#  'news search(singapore) pte. ltd.',
#  'newstead technologies pte ltd',
#  'nexia ts technology pte. ltd.',
#  'ngee chin engineering pte ltd',
#  'ngk software house(s) pte ltd',
#  'niit technologies pte. ltd.',
#  'nityo 3p solutions pte. ltd.',
#  'noisy crayons pte. ltd.',
#  'nokomai studios pte. ltd.',
#  'novacitynets pte ltd',
#  'novaglobal pte ltd',
#  'nsearch global pte. ltd.',
#  'nspire group pte. ltd.',
#  'nsw asia private limited',
#  'ntc integration(pte) ltd',
#  'ntt data business solutions singapore pte. ltd.',
#  'ntt data singapore pte. ltd',
#  'ntuc learninghub pte. ltd.',
#  'nurturing great minds llp',
#  'nuvista technologies pte. ltd.',
#  'nxgen communications pte ltd',
#  "o'connor's singapore pte ltd",
#  'oak consulting pte. ltd.',
#  'om info tech solutions',
#  'omniway solutions pte. ltd.',
#  'one9ninety pte. ltd.',
#  'oneixchange',
#  'onetoone interactive pte. ltd.',
#  'ooi siew lin',
#  'openfeel pte. ltd.',
#  'optimatic pte. ltd.',
#  'optimum solutions(singapore) pte ltd',
#  'oracle corporation singapore pte ltd',
#  'pacific synergy pte ltd',
#  'padang & co pte. ltd.',
#  'palmu asia private limited',
#  'palo it singapore pte. ltd.',
#  'panasonic asia pacific pte. ltd.',
#  'parasoft south east asia pte. ltd.',
#  'parenthexis pte. ltd.',
#  'patmos management services pte. ltd.',
#  'pccw solutions singapore pte. ltd.',
#  'pcs security private limited',
#  'pelicanbrown.com private limited',
#  'pencil group pte. ltd.',
#  'personal e-motion private limited',
#  'phorge group pte. ltd.',
#  'pico pixel pte. ltd.',
#  'pigeonlab pte. ltd.',
#  'pinata studios pte. ltd.',
#  'pinheads interactive pte. ltd.',
#  'pixeloak pte. ltd.',
#  'pkf-cap advisory partners pte. ltd.',
#  'planettel asia pacific pte ltd',
#  'play coding sea llp',
#  'playtivate pte. ltd.',
#  'playware studios pte. ltd.',
#  'pleodata pte. ltd.',
#  'polaris science pte. ltd.',
#  'pratyaya pte. ltd.',
#  'prestige solutions pte. ltd.',
#  'pricewaterhousecoopers consulting(singapore) pte. ltd.',
#  'pricewaterhousecoopers llp',
#  'pricewaterhousecoopers risk services pte. ltd.',
#  'pro-datech systems pte ltd',
#  'production edge pte. ltd.',
#  'proinfocus pte. ltd.',
#  'ptc system(s) pte ltd',
#  'publicitas content pte. ltd.',
#  'pulsesecure pte. ltd.',
#  'puresoftware pte. ltd.',
#  'pwc international assignment services(singapore) pte. ltd.',
#  'qais consulting pte. ltd.',
#  'qg consultancy llp',
#  'quann asia pacific pte. ltd.',
#  'quantum digital solutions pte. ltd.',
#  'quantum information technology pty. ltd.',
#  'qun neng enterprises',
#  'ranosys technologies pte. ltd.',
#  'rapid effect pte ltd',
#  'raptech pte. ltd.',
#  'reachfield it solutions pte. ltd.',
#  'rebl pte. ltd.',
#  'recall total information management pte. ltd.',
#  'red hare studios',
#  'red sentry pte ltd',
#  'rel systems pte. ltd.',
#  'resonance pte ltd',
#  'rjcat consultancy',
#  'rma consultants pte ltd',
#  'roboto llp',
#  'rockmoon pte. ltd.',
#  'roots communications pte ltd',
#  'roots excellence pte ltd',
#  'rps australia west pty ltd',
#  's & i systems pte ltd',
#  's3 innovate pte. ltd.',
#  'sambaash pte. ltd.',
#  'sap asia pte ltd',
#  'sapience consulting pte. ltd.',
#  'screenbox pte ltd',
#  'seacare manpower services pte ltd',
#  'seat of wisdom consultancy services pte. ltd.',
#  'sec consult singapore pte. ltd.',
#  'secom(singapore) pte ltd',
#  'september 21 enterprise pte ltd',
#  'service connections hr consultancy pte. ltd.',
#  'serviont global solutions pte ltd',
#  'servtouch-wywy(singapore) pte. ltd.',
#  'setsco services pte ltd',
#  'sg interactive pte. ltd.',
#  'shatec institutes pte. ltd.',
#  'shinz productions',
#  'sift analytics group pte. ltd.',
#  'sify technologies(singapore) pte. limited',
#  'silver assets pte. ltd.',
#  'simple solution systems pte. ltd.',
#  'simplex consultants pte. ltd.',
#  'simplus pte. ltd.',
#  'singapore communications co pte. ltd.',
#  'singapore learning technologies group pte. ltd.',
#  'singapore telecommunications limited',
#  'singpilot pte. ltd.',
#  'singsys pte. ltd.',
#  'sitespade pte. ltd.',
#  'sky optimum technology pte. ltd.',
#  'smart consulting solutions pte. ltd.',
#  'smartsoft pte. ltd.',
#  'smsdome pte. ltd.',
#  'sodainmind pte. ltd.',
#  'softscheck singapore pte. ltd.',
#  'software ag(singapore) pte ltd',
#  'softworkz pte. ltd.',
#  'solvtify it solutions',
#  'sopra steria asia pte. ltd.',
#  'soverus group pte. ltd.',
#  'soverus kingdom systems pte. ltd.',
#  'sportstats asia pte. ltd.',
#  'sproud private limited',
#  'sql view pte ltd',
#  'st electronics(e-services) pte. ltd.',
#  'st electronics(info-comm systems) pte. ltd.',
#  'st electronics(info-software systems) pte. ltd.',
#  'st electronics(satcom & sensor systems) pte. ltd.',
#  'st integrated engineering pte. ltd.',
#  'st logistics pte. ltd.',
#  'stak apps pte. ltd.',
#  'standard general superintendence & testing laboratory pte ltd',
#  'starhub ltd.',
#  'starvision information technology pte ltd',
#  'strategic digitalab pte. ltd.',
#  'stuck design pte. ltd.',
#  'styl solutions pte. ltd.',
#  'sunpro inno apps pte. ltd.',
#  'sunway digital pte. ltd.',
#  'surbana jurong consultants pte. ltd.',
#  'suzerin pte. ltd.',
#  'sv mobile teleshoppe private limited',
#  'sweet & maxwell asia',
#  'swift integrator pte. ltd.',
#  'swiftx solutions pte. ltd.',
#  'synergy web design',
#  'syspro labs private limited',
#  'systemengineer360 pte. ltd.',
#  'tackle ivs',
#  'tactic public relations',
#  'talariax pte ltd',
#  'talents on tap llp',
#  'tech in asia pte. ltd.',
#  'tech mahindra limited(singapore branch)',
#  'tech six global llp',
#  'tech-men technology pte. ltd.',
#  'techlinkz solutions pte. ltd.',
#  'techlyon pte. ltd.',
#  'technoally pte. ltd.',
#  'techsailor group pte. ltd.',
#  'techserve pte. ltd.',
#  'techtron pte. ltd.',
#  'teck photo',
#  'tejasco techsoft pte. ltd.',
#  'tele-centre services pte ltd',
#  'teleace(s) pte. ltd.',
#  'telescience singapore pte ltd',
#  'teletouch communications sdn. bhd.',
#  'tem trading and services',
#  'terra systems pte. ltd.',
#  'tescom(singapore) software systems testing pte ltd.',
#  'thales solutions asia pte. ltd.',
#  "that's infotech pte. ltd.",
#  'the software practice pte. ltd.',
#  'themozhi pte. ltd.',
#  'thesis pte. ltd.',
#  'thinkfarm pte. ltd.',
#  'thinkplace singapore pte. ltd.',
#  'third sight pte ltd',
#  'thomas management systems pte ltd',
#  'thoughts ware pte ltd',
#  'three learning pte. ltd.',
#  'tindo pte. ltd.',
#  'tj systems(s) pte ltd',
#  'to the point private limited',
#  'total ebiz solutions pte ltd',
#  'toughmen pte. ltd.',
#  'train to transform',
#  'transcend solutions pte. ltd.',
#  'transcentech pte. ltd.',
#  'trimendus pte. ltd.',
#  'true stats lab pte. ltd.',
#  'tuv sud psb pte. ltd.',
#  'twinson computer services',
#  'ufinity pte ltd',
#  'uic asian computer services pte ltd',
#  'unimotion controls pte ltd',
#  'united alarmtronics sdn bhd',
#  'united logistics & distribution(singapore) pte. ltd.',
#  'university of sydney',
#  'upnextedu',
#  'user experience researchers pte. ltd.',
#  'uxarmy pte. ltd.',
#  'valeurhr pte. ltd.',
#  'vectorious',
#  'vectra information security pte ltd',
#  'veev interactive pte. ltd.',
#  'venus enterprises pte. ltd.',
#  'verve technology services pte. ltd.',
#  'verz design pte. ltd.',
#  'verztec consulting pte. ltd.',
#  'vidyatech software services pte. limited',
#  'vinova pte. ltd.',
#  'vintedge pte ltd',
#  'vintedge technologies pte. ltd.',
#  'viperlink pte ltd',
#  'visatech co. ltd.',
#  'vista infosec private limited',
#  'visual factory pte. ltd.',
#  'vivanotion pte. ltd.',
#  'vizansign technologies pte. ltd.',
#  'vizeum singapore pte. ltd.',
#  'viziofly pte. ltd.',
#  'vm education pte. ltd.',
#  'vmray gmbh',
#  'vsolutions pte ltd',
#  'vvolve management consultants pte. ltd.',
#  'web igniter pte. ltd.',
#  'web professional house pte ltd',
#  'web synergies(s) pte ltd',
#  'websparks pte. ltd.',
#  'weighman pte ltd',
#  'white page creation pte. ltd.',
#  'whits technologies',
#  'whooshpro pte. ltd.',
#  'wipro networks pte. limited',
#  'wishbone design consultants llp',
#  'wiz werx pte ltd',
#  'wizlearn technologies pte. ltd.',
#  'wizvision pte. ltd.',
#  'wongsign & ad pte. ltd.',
#  'wormwood pte. ltd.',
#  'ws group pte. ltd.',
#  'wsi laboratory pte. ltd.',
#  'wunderfauks',
#  'xamariners pte ltd',
#  'xjera labs pte. ltd.',
#  'xssist group pte. ltd.',
#  'yamato transport(s) pte ltd',
#  'yokogawa engineering asia pte ltd',
#  'yong lei logistics pte. ltd.',
#  'zencode technologies pte. ltd.',
#  'zenith infotech(s) pte ltd.',
#  'zentech solutions pte. ltd.',
#  'zoliotech pte. ltd.',
#  'zwaan pte. ltd.']

# %%
result['FG']
# Out:
# 0       2
# 1       4
# 2       2
# 3       6
# 4       2
# 5       2
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11     10
# 12      6
# 13      6
# 14      2
# 15      2
# 16      2
# 17      3
# 18      4
# 19      4
# 20      3
# 21      2
# 22      2
# 23      2
# 24      4
# 25      5
# 26      2
# 27      4
# 28      4
# 29      2
#        ..
# 648     6
# 649     3
# 650     5
# 651     4
# 652     5
# 653     2
# 654     2
# 655     2
# 656     2
# 657     9
# 658     2
# 659     3
# 660     2
# 661     5
# 662     2
# 663     4
# 664     2
# 665     2
# 666     2
# 667     3
# 668     3
# 669     2
# 670     3
# 671     5
# 672     2
# 673     3
# 674     3
# 675     2
# 676     2
# 677     2
# Name: FG, Length: 678, dtype: int64

# %%
pickle.dump((new_model,logreg,result),open("training_parameters.pkl","wb"))
